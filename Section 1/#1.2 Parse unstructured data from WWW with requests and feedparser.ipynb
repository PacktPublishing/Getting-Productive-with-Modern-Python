# %%
# Parse unstructured data from WWW with requests and feedparser

# Importing Requests library-
import requests

# Here we get the whole data of the page-
response_json = requests.get('https://github.com/adivyas99/Statistics-for-Data-Science-using-Python')

# Checking if this is the correct responde or not--
# If 200 then correct-
print(response_json.status_code)
# Out:
# 200

# %%
# All Text of the webpage (including all HTML code)--
print(response_json.text)
# Out:
# <!DOCTYPE html>
# <html lang="en">
#   <head>
#     <meta charset="utf-8">
#   <link rel="dns-prefetch" href="https://github.githubassets.com">
#   <link rel="dns-prefetch" href="https://avatars0.githubusercontent.com">
#   <link rel="dns-prefetch" href="https://avatars1.githubusercontent.com">
#   <link rel="dns-prefetch" href="https://avatars2.githubusercontent.com">
#   <link rel="dns-prefetch" href="https://avatars3.githubusercontent.com">
#   <link rel="dns-prefetch" href="https://github-cloud.s3.amazonaws.com">
#   <link rel="dns-prefetch" href="https://user-images.githubusercontent.com/">
#
#
#
#   <link crossorigin="anonymous" media="all" integrity="sha512-HlgX4s+P4ikUGWRu6fvWIVak24jAHDOE7IzlHFtcW54px5zDZvAXO8xY42wXJNZ7PChlgxFwwdMH4tyMFCop6g==" rel="stylesheet" href="https://github.githubassets.com/assets/frameworks-2322f54af916007dd939df6c24bd2264.css" />
# ...

# %%
# To Json format--
print (response_json.json)
# Out:
# <bound method Response.json of <Response [200]>>

# %%
# To get the headers--
print(response_json.headers)
# Out:
# {'Server': 'GitHub.com', 'Date': 'Wed, 10 Apr 2019 19:57:45 GMT', 'Content-Type': 'text/html; charset=utf-8', 'Transfer-Encoding': 'chunked', 'Status': '200 OK', 'Vary': 'X-PJAX', 'ETag': 'W/"af9d4e726cdbda174c68a9833083024f"', 'Cache-Control': 'max-age=0, private, must-revalidate', 'Set-Cookie': 'has_recent_activity=1; path=/; expires=Wed, 10 Apr 2019 20:57:45 -0000, logged_in=no; domain=.github.com; path=/; expires=Sun, 10 Apr 2039 19:57:45 -0000; secure; HttpOnly, _gh_sess=...%3D%3D--82cff890574e1610da160a85132bfd2a79f24c96; path=/; secure; HttpOnly', 'X-Request-Id': '166b125c-1429-4a60-82f7-0191041981f9', 'Strict-Transport-Security': 'max-age=31536000; includeSubdomains; preload', 'X-Frame-Options': 'deny', 'X-Content-Type-Options': 'nosniff', 'X-XSS-Protection': '1; mode=block', 'Expect-CT': 'max-age=2592000, report-uri="https://api.github.com/_private/browser/errors"', 'Content-Security-Policy': "default-src 'none'; base-uri 'self'; block-all-mixed-content; connect-src 'self' u
# ...

# %%
# To check the Text coding--
print(response_json.encoding)

## json_data = json.loads(response_json.text)
# Out:
# utf-8

# %%
# For downloading and parsing syndicated feeds 
# It supports RSS, ATOM, CDF and iTunes extensions
import feedparser

dt = feedparser.parse('http://www.reddit.com/r/python/.rss')

# %%
# For title of the feed--
print (dt['feed']['title'])
# Out:
# Python

# %%
# To see different headers--
print (dt.headers)
# Out:
# {'Content-Type': 'application/atom+xml; charset=UTF-8', 'x-ua-compatible': 'IE=edge', 'x-frame-options': 'SAMEORIGIN', 'x-content-type-options': 'nosniff', 'x-xss-protection': '1; mode=block', 'set-cookie': 'session_tracker=1yz3htFnu47cUo3nsC.0.1554926269305.Z0FBQUFBQmNya3E5SldtQkxWT2RLU3kyZldwWDRvaGVQME1HM254b1FYOUdYTjlWZEE4R0lvUGN6V2tTUXhpX09HNngta1pqZWQwamFpSU9QcTRySklBb0RPNEFOQkN3aUtZemh1Y2NlZHk0dWMyZlV2NW5GM1JrdUxKOG8xc19Xc3N5ZW9GTXNRWGY; Domain=reddit.com; Max-Age=7199; Path=/; expires=Wed, 10-Apr-2019 21:57:49 GMT; secure', 'cache-control': 'max-age=0, must-revalidate', 'X-Moose': 'majestic', 'Content-Length': '40852', 'Accept-Ranges': 'bytes', 'Date': 'Wed, 10 Apr 2019 19:57:49 GMT', 'Via': '1.1 varnish', 'Connection': 'close', 'X-Served-By': 'cache-ams21030-AMS', 'X-Cache': 'MISS', 'X-Cache-Hits': '0', 'X-Timer': 'S1554926269.202026,VS0,VE418', 'Set-Cookie': 'session_tracker=1yz3htFnu47cUo3nsC.0.1554926269305.Z0FBQUFBQmNya3E5SldtQkxWT2RLU3kyZldwWDRvaGVQME1HM254b1FYOUdYTjlWZE
# ...

# %%
# to see the paresed link--
print (dt.entries[0].link)
# Out:
# https://www.reddit.com/r/Python/comments/avrws2/rpython_job_board/
